# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoa20146128/week13/blob/main/pre_trained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 50.8 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/AI/barcelona.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 12/12 [==============================] - 1s 36ms/step
# {'box': [1188, 207, 161, 216], 'confidence': 0.9999999403953552, 'keypoints': {'left_eye': (1227, 283), 'right_eye': (1301, 287), 'nose': (1257, 326), 'mouth_left': (1227, 367), 'mouth_right': (1289, 371)}}
# {'box': [1685, 242, 163, 225], 'confidence': 0.999998152256012, 'keypoints': {'left_eye': (1719, 329), 'right_eye': (1794, 329), 'nose': (1751, 358), 'mouth_left': (1727, 409), 'mouth_right': (1783, 410)}}
# {'box': [2495, 598, 173, 235], 'confidence': 0.9999954104423523, 'keypoints': {'left_eye': (2543, 694), 'right_eye': (2615, 692), 'nose': (2576, 740), 'mouth_left': (2543, 773), 'mouth_right': (2617, 774)}}
# {'box': [1992, 623, 158, 223], 'confidence': 0.9999952912330627, 'keypoints': {'left_eye': (2030, 702), 'right_eye': (2106, 701), 'nose': (2066, 745), 'mouth_left': (2035, 791), 'mouth_right': (2099, 791)}}
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/AI/real.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 2/2 [==============================] - 0s 37ms/step
# {'box': [227, 267, 39, 54], 'confidence': 0.9999694228172302, 'keypoints': {'left_eye': (228, 287), 'right_eye': (241, 284), 'nose': (227, 296), 'mouth_left': (230, 308), 'mouth_right': (241, 305)}}
# {'box': [515, 300, 34, 53], 'confidence': 0.9999169707298279, 'keypoints': {'left_eye': (519, 320), 'right_eye': (526, 321), 'nose': (513, 331), 'mouth_left': (520, 341), 'mouth_right': (526, 341)}}
# {'box': [874, 249, 37, 49], 'confidence': 0.9998907446861267, 'keypoints': {'left_eye': (879, 268), 'right_eye': (895, 267), 'nose': (882, 275), 'mouth_left': (881, 286), 'mouth_right': (893, 286)}}
# {'box': [377, 272, 31, 49], 'confidence': 0.9958221912384033, 'keypoints': {'left_eye': (381, 293), 'right_eye': (384, 286), 'nose': (380, 298), 'mouth_left': (389, 310), 'mouth_right': (392, 305)}}

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/AI/barcelona.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill = False, color='white')
  ax.add_patch(rect)
  plt.savefig('/content/drive/MyDrive/AI/nhieumat.png')
plt.show()
# Out:
# ...
# 12/12 [==============================] - 2s 113ms/step

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/AI/real.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill = False, color='white')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 55ms/step

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '/content/drive/MyDrive/AI/barcelona.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill = False, color='white')
  ax.add_patch(rect)
  #plt.savefig('/content/drive/MyDrive/AI/nhieumat.png')
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value,radius =5, color = 'white')
    ax.add_patch(dot)
  plt.savefig('/content/drive/MyDrive/AI/nhieumatcocham.png')
plt.show()
# Out:
# ...
# 12/12 [==============================] - 1s 40ms/step

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1+width, y1+height
    plt.subplot(1, len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()
filename = '/content/drive/MyDrive/AI/barcelona.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 12/12 [==============================] - 1s 44ms/step
